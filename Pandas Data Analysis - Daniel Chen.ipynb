# %% [markdown]
# #### Based on the Pandas video tutorials by Daniel Chen on O'Reilly

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = sns.load_dataset('anscombe')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
len(data)
# Out:
# 44

# %%
plt.plot(data['x'], data['y'])

plt.show()

# %%
plt.plot(data['x'], data['y'], 'o')

plt.show()

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig=plt.figure()

# %%
axes1=fig.add_subplot(1,1,1)
axes1.hist(tips['total_bill'], bins=15)
fig.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
x = pd.DataFrame({'Name':['Nikhil Sharma', 'Ankit Sharma']})

# %%
x
# Out:
#             Name
# 0  Nikhil Sharma
# 1   Ankit Sharma

# %%
x['Name'].str.split(' ')
# Out:
# 0    [Nikhil, Sharma]
# 1     [Ankit, Sharma]
# Name: Name, dtype: object

# %%
name_split = x['Name'].str.split(' ')

# %%
type(name_split) # this returns a Series
# Out:
# pandas.core.series.Series

# %%
name_split
# Out:
# 0    [Nikhil, Sharma]
# 1     [Ankit, Sharma]
# Name: Name, dtype: object

# %%
first_name = name_split.str.get(0)

# %%
first_name
# Out:
# 0    Nikhil
# 1     Ankit
# Name: Name, dtype: object

# %%
last_name = name_split.str.get(1)

# %%
last_name
# Out:
# 0    Sharma
# 1    Sharma
# Name: Name, dtype: object

# %%
x['first name']=first_name

# %%
x['last name']=last_name

# %%
x
# Out:
#             Name first name last name
# 0  Nikhil Sharma     Nikhil    Sharma
# 1   Ankit Sharma      Ankit    Sharma

# %%
name_split2 = x['Name'].str.split(' ', expand=True)

# %%
# let's try this split thing using 'expand' option

# %%
type(name_split2) # this returns a Data Frame
# Out:
# pandas.core.frame.DataFrame

# %%
name_split2 # now this dataframe can directly be concatenated to the existing dataframe
# Out:
#         0       1
# 0  Nikhil  Sharma
# 1   Ankit  Sharma

# %% [markdown]
# #### Datatypes

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips['sex str'] = tips['sex'].astype('str') # using astype to convert categorical data to string data

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size sex str
# 0       16.99  1.01  Female     No  Sun  Dinner     2  Female
# 1       10.34  1.66    Male     No  Sun  Dinner     3    Male
# 2       21.01  3.50    Male     No  Sun  Dinner     3    Male
# 3       23.68  3.31    Male     No  Sun  Dinner     2    Male
# 4       24.59  3.61  Female     No  Sun  Dinner     4  Female

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
#  7   sex str     244 non-null    object
# dtypes: category(4), float64(2), int64(1), object(1)
# memory usage: 9.2+ KB

# %%
x
# Out:
#             Name first name last name
# 0  Nikhil Sharma     Nikhil    Sharma
# 1   Ankit Sharma      Ankit    Sharma

# %%
x['value'] = [0, 'zero']

# %%
x
# Out:
#             Name first name last name value
# 0  Nikhil Sharma     Nikhil    Sharma     0
# 1   Ankit Sharma      Ankit    Sharma  zero

# %%
x['value'].astype(float) # this will give error that 'zero' cannot be converted to float

# %%
x['value'] = pd.to_numeric(x['value'], errors='coerce') # use to_numeric with errors=coerce

# %%
x # errors = 'coerce' converts 'zero' to NaN
# Out:
#             Name first name last name  value
# 0  Nikhil Sharma     Nikhil    Sharma    0.0
# 1   Ankit Sharma      Ankit    Sharma    NaN

# %% [markdown]
# #### Functions

# %%
def multiply_99(x):
    return x*99

# %%
x
# Out:
#             Name first name last name  value
# 0  Nikhil Sharma     Nikhil    Sharma    0.0
# 1   Ankit Sharma      Ankit    Sharma    NaN

# %%
x['scores']=[2,3]

# %%
x
# Out:
#             Name first name last name  value  scores
# 0  Nikhil Sharma     Nikhil    Sharma    0.0       2
# 1   Ankit Sharma      Ankit    Sharma    NaN       3

# %%
multiply_99(x['scores'])
# Out:
# 0    198
# 1    297
# Name: scores, dtype: int64

# %%
x.apply(multiply_99) # applying function to the whole dataframe
# Out:
#                                                 Name  \
# 0  Nikhil SharmaNikhil SharmaNikhil SharmaNikhil ...
# 1  Ankit SharmaAnkit SharmaAnkit SharmaAnkit Shar...
#
#                                           first name  \
# 0  NikhilNikhilNikhilNikhilNikhilNikhilNikhilNikh...
# 1  AnkitAnkitAnkitAnkitAnkitAnkitAnkitAnkitAnkitA...
#
#                                            last name  value  scores
# 0  SharmaSharmaSharmaSharmaSharmaSharmaSharmaShar...    0.0     198
# 1  SharmaSharmaSharmaSharmaSharmaSharmaSharmaShar...    NaN     297

# %%
x[['scores']].apply(multiply_99, axis=0) # using 'apply' column-wise
# Out:
#    scores
# 0     198
# 1     297

# %%
# Also np.vectorize() can be used to vectorize a function
